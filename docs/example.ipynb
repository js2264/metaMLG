# %% [markdown]
# # Example usage
#
# Demonstration of `metamlg` functionalities.

# %% [markdown]
# ## Imports

# %%
from metamlg.metamlg import count_words
from metamlg.plot import plot_words
print(metamlg.__version__)
# Out:
# 0.1.0

# %% [markdown]
# ## Execute

# %%
with open("tmp.txt", "w") as file: 
    file.write("First half of Jupyter Notebook demonstrating an example workflow using the pycounts package")
    
wds = count_words("tmp.txt")
print(wds)
# Out:
# Counter({'first': 1, 'half': 1, 'of': 1, 'jupyter': 1, 'notebook': 1, 'demonstrating': 1, 'an': 1, 'example': 1, 'workflow': 1, 'using': 1, 'the': 1, 'pycounts': 1, 'package': 1})

# %%
plot_words(wds)
# Out:
# <BarContainer object of 10 artists>
